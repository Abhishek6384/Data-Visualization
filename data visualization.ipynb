# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
X=np.random.randn(1000)

# %%
plt.hist(X,100)
plt.title("Normal distribution")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.xlabel("range")
plt.ylabel("frequency")
# Out:
# Text(41.625, 0.5, 'frequency')

# %%
import pandas as pd

# %%
df=pd.DataFrame([[8880,5123],[8670,6682],[8147,3380],[7333,1862]],columns=['India','China'])

# %%
df.plot(kind='line')
# Out:
# <img src="data:image/png;base64,..." width="432">
# <AxesSubplot:>

# %%
df.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="432">
# <AxesSubplot:>

# %%
df.plot(kind='hist')
# Out:
# <img src="data:image/png;base64,..." width="432">
# <AxesSubplot:ylabel='Frequency'>

# %%
pd.read_csv('Canada.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-447fae6f25dc> in <module>
# ----> 1 pd.read_csv('Canada.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
# ...

# %%
df.plot(kind='line')
# Out:
# <img src="data:image/png;base64,..." width="432">
# <AxesSubplot:>

# %%
pd.read_csv('Canada.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-447fae6f25dc> in <module>
# ----> 1 pd.read_csv('Canada.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
# ...

# %%
xls=pd.read_excel('Canada.xlsx','Regions by Citizenship')
xls
# Out:
#                                            Unnamed: 0  Unnamed: 1  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                      United Nations         NaN
# 4                                 Population Division         NaN
# 5           Department of Economic and Social Affairs         NaN
# 6                                                 NaN         NaN
# 7   International Migration Flows to and from Sele...         NaN
# 8                                                 NaN         NaN
# 9                            POP/DB/MIG/Flow/Rev.2015         NaN
# 10  December 2015 - Copyright © 2015 by United Nat...         NaN
# 11  Suggested citation: United Nations, Department...         NaN
# 12   International Migration Flows to and from Sel...         NaN
# ...
