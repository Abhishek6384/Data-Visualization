# %%
import pandas as pd

# %%
df=pd.read_csv('weatherHistory.csv')

# %%
df.head(5)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df.loc[0] #getting the 1std row
# Out:
# Formatted Date                  2006-04-01 00:00:00.000 +0200
# Summary                                         Partly Cloudy
# Precip Type                                              rain
# Temperature (C)                                       9.47222
# Apparent Temperature (C)                              7.38889
# Humidity                                                 0.89
# Wind Speed (km/h)                                     14.1197
# Wind Bearing (degrees)                                    251
# Visibility (km)                                       15.8263
# Loud Cover                                                  0
# Pressure (millibars)                                  1015.13
# Daily Summary               Partly cloudy throughout the day.
# Name: 0, dtype: object

# %%
df.loc[300] #getting the 300th row
# Out:
# Formatted Date                                  2006-04-20 12:00:00.000 +0200
# Summary                                                         Partly Cloudy
# Precip Type                                                              rain
# Temperature (C)                                                       15.0722
# Apparent Temperature (C)                                              15.0722
# Humidity                                                                 0.86
# Wind Speed (km/h)                                                      3.2844
# Wind Bearing (degrees)                                                    120
# Visibility (km)                                                        6.3434
# Loud Cover                                                                  0
# Pressure (millibars)                                                  1014.92
# Daily Summary               Foggy starting overnight continuing until morn...
# Name: 300, dtype: object

# %%
# to get the last row
df.tail(1)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 96452               1016.16  Partly cloudy starting in the morning.

# %%
# select the first, 100th, and 1000th rows
df.loc[[0,99,999]]
# Out:
#                     Formatted Date        Summary Precip Type  \
# 0    2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 99   2006-04-13 03:00:00.000 +0200       Overcast        rain
# 999  2006-08-02 15:00:00.000 +0200  Mostly Cloudy        rain
#
#      Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0           9.472222                  7.388889      0.89            14.1197
# 99          7.200000                  4.550000      0.76            14.4739
# 999        24.961111                 24.961111      0.62            15.8746
#
#      Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                     251.0          15.8263         0.0
# 99                    273.0          15.8263         0.0
# 999                   290.0          11.2700         0.0
#
#      Pressure (millibars)                      Daily Summary
# 0                 1015.13  Partly cloudy throughout the day.
# ...

# %%
# get the 2nd row
df.iloc[1]
# Out:
# Formatted Date                  2006-04-01 01:00:00.000 +0200
# Summary                                         Partly Cloudy
# Precip Type                                              rain
# Temperature (C)                                       9.35556
# Apparent Temperature (C)                              7.22778
# Humidity                                                 0.86
# Wind Speed (km/h)                                     14.2646
# Wind Bearing (degrees)                                    259
# Visibility (km)                                       15.8263
# Loud Cover                                                  0
# Pressure (millibars)                                  1015.63
# Daily Summary               Partly cloudy throughout the day.
# Name: 1, dtype: object

# %%
# •get the 100th row
df.iloc[99]
# Out:
# Formatted Date              2006-04-13 03:00:00.000 +0200
# Summary                                          Overcast
# Precip Type                                          rain
# Temperature (C)                                       7.2
# Apparent Temperature (C)                             4.55
# Humidity                                             0.76
# Wind Speed (km/h)                                 14.4739
# Wind Bearing (degrees)                                273
# Visibility (km)                                   15.8263
# Loud Cover                                              0
# Pressure (millibars)                              1007.28
# Daily Summary                Overcast throughout the day.
# Name: 99, dtype: object

# %%
# using -1 to get the last row
df.iloc[-1]
# Out:
# Formatted Date                       2016-09-09 23:00:00.000 +0200
# Summary                                              Partly Cloudy
# Precip Type                                                   rain
# Temperature (C)                                            20.4389
# Apparent Temperature (C)                                   20.4389
# Humidity                                                      0.61
# Wind Speed (km/h)                                           5.8765
# Wind Bearing (degrees)                                          39
# Visibility (km)                                            15.5204
# Loud Cover                                                       0
# Pressure (millibars)                                       1016.16
# Daily Summary               Partly cloudy starting in the morning.
# Name: 96452, dtype: object

# %%
# get the first, 100th, and 1000th rows
df.iloc[[10,99,999]]
# Out:
#                     Formatted Date        Summary Precip Type  \
# 10   2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain
# 99   2006-04-13 03:00:00.000 +0200       Overcast        rain
# 999  2006-08-02 15:00:00.000 +0200  Mostly Cloudy        rain
#
#      Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 10         16.016667                 16.016667      0.67            17.5651
# 99          7.200000                  4.550000      0.76            14.4739
# 999        24.961111                 24.961111      0.62            15.8746
#
#      Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 10                    290.0          11.2056         0.0
# 99                    273.0          15.8263         0.0
# 999                   290.0          11.2700         0.0
#
#      Pressure (millibars)                      Daily Summary
# 10                1017.42  Partly cloudy throughout the day.
# ...

# %%
# to get the columns
subset=df.loc[:,['Summary','Humidity']]
subset.head(4)
# Out:
#          Summary  Humidity
# 0  Partly Cloudy      0.89
# 1  Partly Cloudy      0.86
# 2  Mostly Cloudy      0.89
# 3  Partly Cloudy      0.83

# %%
# subset columns with iloc
 # iloc will alow us to use integers
 # -1 will select the last column
subset=df.iloc[:,[0,1]]
subset.head(6)
# Out:
#                   Formatted Date        Summary
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy

# %%
small_Range=list(range(4))
small_Range
# Out:
# [0, 1, 2, 3]

# %%
subset=df.iloc[:,small_Range]
subset.head(5)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556

# %%
# Subsetting Rows and Columns

subset=df.iloc[10,small_Range]
subset
# Out:
# Formatted Date     2006-04-01 10:00:00.000 +0200
# Summary                            Partly Cloudy
# Precip Type                                 rain
# Temperature (C)                          16.0167
# Name: 10, dtype: object

# %%
subset=df.loc[10,'Summary']
subset
# Out:
# 'Partly Cloudy'

# %%
#get the 1st, 100th, and 1000th rows
# from the 1st, 4th, and 6th columns
subset=df.iloc[[10,20,30],small_Range]
subset
# Out:
#                    Formatted Date        Summary Precip Type  Temperature (C)
# 10  2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain        16.016667
# 20  2006-04-01 20:00:00.000 +0200  Mostly Cloudy        rain        11.550000
# 30  2006-04-10 06:00:00.000 +0200  Mostly Cloudy        rain         7.261111

# %%
# using loc 
subset=df.loc[[10,20,30],['Summary','Temperature (C)']]
subset
# Out:
#           Summary  Temperature (C)
# 10  Partly Cloudy        16.016667
# 20  Mostly Cloudy        11.550000
# 30  Mostly Cloudy         7.261111

# %%
subset=df.loc[10:15,['Summary','Temperature (C)']]
subset
# Out:
#           Summary  Temperature (C)
# 10  Partly Cloudy        16.016667
# 11  Partly Cloudy        17.144444
# 12  Partly Cloudy        17.800000
# 13  Partly Cloudy        17.333333
# 14  Partly Cloudy        18.877778
# 15  Partly Cloudy        18.911111

# %%
df.groupby('Summary')['Temperature (C)'].mean()
# Out:
# Summary
# Breezy                                  7.922016
# Breezy and Dry                         21.111111
# Breezy and Foggy                       -0.510317
# Breezy and Mostly Cloudy               11.093411
# Breezy and Overcast                     7.241614
# Breezy and Partly Cloudy               12.492761
# Clear                                  11.925109
# Dangerously Windy and Partly Cloudy     8.944444
# Drizzle                                10.847578
# Dry                                    29.083660
# Dry and Mostly Cloudy                  26.838492
# Dry and Partly Cloudy                  26.605749
# Foggy                                   1.464035
# Humid and Mostly Cloudy                20.886389
# Humid and Overcast                     21.515079
# Humid and Partly Cloudy                21.568301
# Light Rain                             10.021517
# Mostly Cloudy                          12.629334
# Overcast                                7.516502
# ...

# %%
from matplotlib import pyplot as plt

# %%
df_summary=df.groupby('Summary' ,axis=0).sum()
df_summary
# Out:
#                                      Temperature (C)  \
# Summary
# Breezy                                    427.788889
# Breezy and Dry                             21.111111
# Breezy and Foggy                          -17.861111
# Breezy and Mostly Cloudy                 5724.200000
# Breezy and Overcast                      3823.572222
# Breezy and Partly Cloudy                 4822.205556
# Clear                                  129864.438889
# Dangerously Windy and Partly Cloudy         8.944444
# Drizzle                                   423.055556
# Dry                                       988.844444
# Dry and Mostly Cloudy                     375.738889
# Dry and Partly Cloudy                    2288.094444
# Foggy                                   10464.922222
# Humid and Mostly Cloudy                   835.455556
# Humid and Overcast                        150.605556
# Humid and Partly Cloudy                   366.661111
# ...

# %%
df_summary['Humidity'].plot(kind='pie')
plt.title('humidity')
plt.show()

# %%
df_breezy=df.iloc[[0],[3]].transpose()
df_breezy.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
new_df=df_summary[['Humidity','Temperature (C)']]
df_summary.plot(kind='line',x='Temperature (C)',y='Humidity')
# Out:
# <AxesSubplot:xlabel='Temperature (C)'>
